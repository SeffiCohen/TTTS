# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
import time
import numpy as np
import pandas as pd
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score, f1_score, log_loss, accuracy_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.datasets import load_breast_cancer,fetch_lfw_pairs,load_digits,load_iris,load_wine

from art.attacks.evasion import FastGradientMethod,AutoProjectedGradientDescent,ThresholdAttack
from art.attacks.evasion import ZooAttack,HopSkipJump, BoundaryAttack, DecisionTreeAttack
from art.attacks.evasion import HighConfidenceLowUncertainty, ProjectedGradientDescent

from art.estimators.classification import SklearnClassifier

# %%
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import _tree
from sklearn.utils.validation import check_is_fitted


class MonteCarloRandomForestClassifier(RandomForestClassifier):
    def __init__(self, prob_type='fixed', *args, **kwargs):
        super().__init__(*args, **kwargs)
        if prob_type not in ['fixed', 'depth', 'certainty', 'agreement', 'bayes', 'confidence','distance']:
            raise ValueError('Invalid prob_type')
        self.prob_type = prob_type

    def get_depth_based_probability(self, depth):
        return min(0.05 * depth, 0.2)

    def get_certainty_based_probability(self, node_id, tree):
        node_values = tree.value[node_id].flatten()
        total = np.sum(node_values)
        distribution = node_values / total
        max_certainty = np.max(distribution)
        p = 0.5 - max_certainty
        return max(p, 0)

    def get_agreement_based_probability(self, node_id, tree):
        node_values = tree.value[node_id].flatten()
        majority_class_ratio = np.max(node_values) / np.sum(node_values)
        p = 0.5 - majority_class_ratio
        return max(p, 0)

    def get_confidence_based_probability(self, X, node_id, sample, tree):
        feature_index = tree.feature[node_id]
        if feature_index == _tree.TREE_UNDEFINED:
            return 0

        feature_values = X[:, feature_index]
        avg = np.mean(feature_values)
        std = np.std(feature_values)

        distance = abs(sample[feature_index] - avg)
        p = max(0.5 - (distance / (std + 1e-9)), 0)
        return p

    def get_bayes_based_probability(self, node_id, sample, tree):
        if tree.children_left[node_id] == _tree.TREE_LEAF or tree.children_right[node_id] == _tree.TREE_LEAF:
            # Can't calculate Bayesian probability at the leaf node.
            return 0

        parent_values = tree.value[node_id].flatten()
        parent_samples = np.sum(parent_values)
        
        left_child_values = tree.value[tree.children_left[node_id]].flatten()
        right_child_values = tree.value[tree.children_right[node_id]].flatten()
        
        prior = np.max(parent_values) / parent_samples
        
        left_majority_ratio = np.max(left_child_values) / np.sum(left_child_values)
        right_majority_ratio = np.max(right_child_values) / np.sum(right_child_values)
        likelihood = left_majority_ratio * right_majority_ratio
        
        marginal_likelihood = np.mean([left_majority_ratio, right_majority_ratio])
        
        posterior = likelihood * (prior / (marginal_likelihood + 1e-9))
        
        p = 0.5 - posterior
        # Return the scaled posterior
        return max(p, 0)

    def get_distance_based_probability(self, X,tree, node_id, sample):
        feature_index = tree.feature[node_id]
        if feature_index == _tree.TREE_UNDEFINED:
            return 0
        
        threshold = tree.threshold[node_id]
        feature_value = sample[feature_index]
        feature_values = X[:, feature_index]
        distance = abs(feature_value - threshold)
        std = np.std(feature_values)
        
        # The closer the distance is to 0, the lower the probability
        p =  max(0.5 - (distance / (std + 1e-9)), 0) 
        
        return p
    
    def traverse_tree(self, tree, node, sample, X, depth=0):
        if self.prob_type == 'fixed':
            p = 0.05
        elif self.prob_type == 'depth':
            p = self.get_depth_based_probability(depth)
        elif self.prob_type == 'certainty':
            p = self.get_certainty_based_probability(node, tree)
        elif self.prob_type == 'agreement':
            p = self.get_agreement_based_probability(node, tree)
        elif self.prob_type == 'confidence':
            p = self.get_confidence_based_probability(X, node, sample, tree)
        elif self.prob_type == 'bayes':
            p = self.get_bayes_based_probability(node, sample, tree)
        elif self.prob_type == 'distance':
            p = self.get_distance_based_probability(X,tree, node, sample)
        else:
            raise ValueError('Invalid prob_type')

        if tree.feature[node] != _tree.TREE_UNDEFINED:
            if sample[tree.feature[node]] <= tree.threshold[node]:
                if np.random.rand() > p:
                    return self.traverse_tree(tree, tree.children_left[node], sample, X, depth + 1)
                else:
                    return self.traverse_tree(tree, tree.children_right[node], sample, X, depth + 1)
            else:
                if np.random.rand() > p:
                    return self.traverse_tree(tree, tree.children_right[node], sample, X, depth + 1)
                else:
                    return self.traverse_tree(tree, tree.children_left[node], sample, X, depth + 1)
        else:
            return tree.value[node]

    def predict_proba(self, X, n_simulations=100):
        check_is_fitted(self)
        X = self._validate_X_predict(X)

        proba = []
        for x in X:
            simulation_results = []
            for tree in self.estimators_:
                tree_results = [self.traverse_tree(tree.tree_, 0, x, X).ravel() for _ in range(n_simulations)]
                simulation_results.extend(tree_results)
            mean_proba = np.mean(simulation_results, axis=0)
            proba.append(mean_proba)

        return np.array(proba)

# %%
import pandas as pd
from sklearn.utils import Bunch
from joblib import Parallel, delayed

# Base path where the files are stored
base_path = 'Experiments/'

# List of files
dataset_list = ['!ar4.csv', '!bodyfat.csv', 'Kaggle_Surgical-deepnet.csv', 'MaternalBinary.csv', 'OPENML_philippine.csv', 'AcousticExtinguisherFire.csv', 'acute-inflammation.csv', 'acute-nephritis.csv', 'AP_Colon_Lung.csv', 'backache.csv', 'blood.csv', 'chess-krvkp.csv', 'cloud.csv', 'congressional-voting.csv', 'credit-approval.csv', 'dresses-salesN.csv', 'echocardiogram.csv', 'haberman-survival.csv', 'heart_failure_clinical_records_dataset.csv', 'heart-hungarian.csv', 'hill-valley.csv', 'horse-colic.csv', 'ilpd-indian-liver.csv', 'no2.csv', 'kaggle_REWEMA.csv', 'lowbwt.csv', 'madelon.csv', 'Mesothelioma.csv', 'MIMIC2.csv', 'molec-biol-promoter.csv', 'oil_spill.csv', 'oocytes_merluccius_nucleus_4d.csv', 'oocytes_trisopterus_nucleus_2f.csv', 'ozone.csv', 'Parkinson_Multiple_Sound_Recording.csv', 'PC1 Software defect prediction.csv', 'pd_speech_features.csv', 'pima.csv', 'Pistachio_28_Features_Dataset.csv', 'plasma_retinol.csv', 'primary-tumorNumeric.csv', 'seismic-bumps.csv', 'sleuth_case2002.csv', 'spambase.csv', 'spect.csv', 'spectf.csv', 'statlog-australian-credit.csv', 'statlog-heart_.csv', 'ThoraricSurgery.csv', 'triazines.csv' ]

# Function to load dataset
def load_dataset(file_name, path):
    try:
        data = pd.read_csv(path + file_name)
        # Use all columns except the last one as features
        X = data.iloc[:, :-1]
        # Use the last column as the target class
        y = data.iloc[:, -1]
        return (file_name, Bunch(data=X, target=y))
    except Exception as e:
        print(f"Error loading {file_name}: {e}")
        return None

# Parallel loading of datasets (using all available cores with n_jobs=-1)
datasets = Parallel(n_jobs=-1)(delayed(load_dataset)(file_name, base_path) for file_name in dataset_list)

# Filter out None values in case of loading errors
datasets = [dataset for dataset in datasets if dataset is not None]

# Now 'datasets' is a list of tuples, where each tuple contains file_name and the corresponding dataset as a Bunch object.

# %%
from joblib import Parallel, delayed
import time
from sklearn.model_selection import StratifiedKFold
from sklearn.ensemble import RandomForestClassifier
from art.defences.preprocessor import FeatureSqueezing,GaussianAugmentation
from sklearn.metrics import roc_auc_score, f1_score, log_loss, accuracy_score

# Assuming that MonteCarloRandomForestClassifier is imported or defined elsewhere

# 5-fold cross-validation
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# List to store evaluation results
results = []

# Define classifiers
classifiers = {
    'RandomForest':  RandomForestClassifier(random_state=123,n_estimators=10),
    'MonteCarloRandomForest_Fix_Prob':  MonteCarloRandomForestClassifier(random_state=123,prob_type='fixed',n_estimators=10),
    'MonteCarloRandomForest_Depth_Prob':  MonteCarloRandomForestClassifier(random_state=123,prob_type='depth',n_estimators=10),
    'MonteCarloRandomForest_Agreement_Prob':  MonteCarloRandomForestClassifier(random_state=123,prob_type='agreement',n_estimators=10),
    'MonteCarloRandomForest_Bayes_Prob':  MonteCarloRandomForestClassifier(random_state=123,prob_type='bayes',n_estimators=10),
    'MonteCarloRandomForest_Confidence_Prob':  MonteCarloRandomForestClassifier(random_state=123,prob_type='confidence',n_estimators=10),
    'MonteCarloRandomForest_Distance_Prob':  MonteCarloRandomForestClassifier(random_state=123,prob_type='distance',n_estimators=10),
    'FeatureSqueezing': RandomForestClassifier(random_state=123,n_estimators=10),
 #   'GaussianAugmentation_DecisionTreeAttack': DecisionTreeClassifier(random_state=123),
}

def evaluate_classifier(dataset_name, dataset, clf_name, clf, train_index, test_index):
    X, y = dataset.data.fillna(0).values, dataset.target
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

    # Train classifier
    start_time = time.time()
    clf.fit(X_train, y_train)

    # Predict
    pred_probs = clf.predict_proba(X_test)
    preds = clf.predict(X_test)
    runtime = time.time() - start_time

    # Evaluate
    auc = roc_auc_score(y_test, pred_probs[:, 1], multi_class='ovr')
    f1 = f1_score(y_test, preds, average='macro')
    logloss = log_loss(y_test, pred_probs)
    accuracy = accuracy_score(y_test, preds)

    return [dataset_name, clf_name, auc, f1, logloss, accuracy, runtime]

# Loop through datasets
all_tasks = []

for dataset_name, dataset in datasets:
    print(dataset_name)
    X, y = dataset.data.fillna(0).values, dataset.target
    
    # Perform 5-fold cross-validation
    for clf_name, clf in classifiers.items():
        for i, (train_index, test_index) in enumerate(skf.split(X, y)):
            task = delayed(evaluate_classifier)(dataset_name, dataset, clf_name, clf, train_index, test_index)
            all_tasks.append(task)

# Execute all tasks in parallel
results = Parallel(n_jobs=-1)(all_tasks)

# Convert results to DataFrame for easy visualization
results_df_wo_rf = pd.DataFrame(results, columns=['Dataset', 'Classifier', 'AUC', 'F1', 'LogLoss', 'Accuracy', 'Runtime'])
# Out:
# !ar4.csv
# !bodyfat.csv
# Kaggle_Surgical-deepnet.csv
# MaternalBinary.csv
# OPENML_philippine.csv
# AcousticExtinguisherFire.csv
# acute-inflammation.csv
# acute-nephritis.csv
# AP_Colon_Lung.csv
# backache.csv
# blood.csv
# chess-krvkp.csv
# cloud.csv
# congressional-voting.csv
# credit-approval.csv
# dresses-salesN.csv
# echocardiogram.csv
# haberman-survival.csv
# heart_failure_clinical_records_dataset.csv
# heart-hungarian.csv
# hill-valley.csv
# horse-colic.csv
# ilpd-indian-liver.csv
# no2.csv
# kaggle_REWEMA.csv
# lowbwt.csv
# madelon.csv
# Mesothelioma.csv
# MIMIC2.csv
# molec-biol-promoter.csv
# oil_spill.csv
# oocytes_merluccius_nucleus_4d.csv
# oocytes_trisopterus_nucleus_2f.csv
# ozone.csv
# Parkinson_Multiple_Sound_Recording.csv
# PC1 Software defect prediction.csv
# pd_speech_features.csv
# pima.csv
# Pistachio_28_Features_Dataset.csv
# plasma_retinol.csv
# primary-tumorNumeric.csv
# seismic-bumps.csv
# sleuth_case2002.csv
# spambase.csv
# spect.csv
# spectf.csv
# statlog-australian-credit.csv
# statlog-heart_.csv
# ThoraricSurgery.csv
# triazines.csv

# %%
summary_wo = results_df_wo_rf.groupby(['Dataset','Classifier']).agg({
    'AUC': ['mean', 'std'],
    'F1': ['mean', 'std'],
    'LogLoss': ['mean', 'std'],
    'Accuracy': ['mean', 'std'],
    'Runtime': ['mean', 'std']
}).reset_index()

print(summary_wo)
# Out:
#            Dataset                              Classifier       AUC  \
#                                                                 mean
# 0         !ar4.csv                        FeatureSqueezing  0.844935
# 1         !ar4.csv   MonteCarloRandomForest_Agreement_Prob  0.832516
# 2         !ar4.csv       MonteCarloRandomForest_Bayes_Prob  0.835458
# 3         !ar4.csv  MonteCarloRandomForest_Confidence_Prob  0.858987
# 4         !ar4.csv       MonteCarloRandomForest_Depth_Prob  0.827614
# ..             ...                                     ...       ...
# 395  triazines.csv  MonteCarloRandomForest_Confidence_Prob  0.782213
# 396  triazines.csv       MonteCarloRandomForest_Depth_Prob  0.796726
# 397  triazines.csv    MonteCarloRandomForest_Distance_Prob  0.820649
# 398  triazines.csv         MonteCarloRandomForest_Fix_Prob  0.832251
# 399  triazines.csv                            RandomForest  0.796607
#
#                      F1             LogLoss            Accuracy            \
#           std      mean       std      mean       std      mean       std
# 0    0.136945  0.667405  0.140511  1.540282  2.093883  0.841558  0.051208
# 1    0.121583  0.695854  0.062722  1.578587  2.086582  0.859740  0.033859
# 2    0.123365  0.695854  0.062722  1.581197  2.084670  0.859740  0.033859
# 3    0.090439  0.695854  0.062722  0.543901  0.087171  0.859740  0.033859
# 4    0.138248  0.695854  0.062722  0.441458  0.061542  0.859740  0.033859
# ..        ...       ...       ...       ...       ...       ...       ...
# 395  0.113582  0.748982  0.086778  0.653177  0.037531  0.763016  0.082978
# 396  0.099239  0.779872  0.091730  0.663869  0.011381  0.795306  0.085358
# 397  0.097741  0.769600  0.106931  0.562006  0.112196  0.784495  0.100040
# 398  0.070001  0.775425  0.079937  0.634315  0.024690  0.790043  0.073258
# 399  0.053055  0.731975  0.048857  1.724981  0.520469  0.747226  0.045696
#
#        Runtime
#           mean       std
# 0     0.040418  0.016927
# 1     5.726762  0.878909
# 2    15.405564  4.005029
# 3    13.278236  1.032877
# 4     1.305286  0.324046
# ..         ...       ...
# 395  38.976595  2.738431
# 396   4.068225  0.930125
# 397  36.237296  3.542921
# 398   3.934860  0.694603
# 399   0.035982  0.013820
#
# [400 rows x 12 columns]

# %%
from joblib import Parallel, delayed
import time
from sklearn.model_selection import StratifiedKFold
from sklearn.ensemble import RandomForestClassifier
from art.defences.preprocessor import FeatureSqueezing,GaussianAugmentation
from sklearn.metrics import roc_auc_score, f1_score, log_loss, accuracy_score

# Assuming that MonteCarloRandomForestClassifier is imported or defined elsewhere

# 5-fold cross-validation
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# List to store evaluation results
results = []

# Define classifiers
# Define classifiers
classifiers = {
    'RandomForest_ZooAttack':  RandomForestClassifier(random_state=123,n_estimators=10),
    'MonteCarloRandomForest_Fix_Prob_ZooAttack':  MonteCarloRandomForestClassifier(random_state=123,prob_type='fixed',n_estimators=10),
    'MonteCarloRandomForest_Depth_Prob_ZooAttack':  MonteCarloRandomForestClassifier(random_state=123,prob_type='depth',n_estimators=10),
    'MonteCarloRandomForest_Agreement_Prob_ZooAttack':  MonteCarloRandomForestClassifier(random_state=123,prob_type='agreement',n_estimators=10),
    'MonteCarloRandomForest_Confidence_Prob_ZooAttack':  MonteCarloRandomForestClassifier(random_state=123,prob_type='confidence',n_estimators=10),
    'MonteCarloRandomForest_Distance_Prob_ZooAttack':  MonteCarloRandomForestClassifier(random_state=123,prob_type='distance',n_estimators=10),
    'FeatureSqueezing_ZooAttack': RandomForestClassifier(random_state=123,n_estimators=10),
}


def evaluate_classifier(dataset_name, dataset, clf_name, clf, train_index, test_index):
    X, y = dataset.data.fillna(0).values, dataset.target
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

    # Train classifier
    clf.fit(X_train, y_train)

    if clf_name != 'RandomForest_ZooAttack':
        dummy_clf = RandomForestClassifier(random_state=123,n_estimators=10)
        dummy_clf.fit(X_train, y_train)
        classifier = SklearnClassifier(model=dummy_clf, use_logits=True)
    else:
        classifier = SklearnClassifier(model=clf, use_logits=True)
        
    attack = ZooAttack(classifier=classifier, confidence=0.0, targeted=False, learning_rate=1e-1, max_iter=5,
           binary_search_steps=5, initial_const=1e-3, abort_early=True, use_resize=False, 
           use_importance=False, nb_parallel=2, batch_size=1, variable_h=0.2) 
    x_test_adv = attack.generate(x=X_test)
    
    if clf_name == 'FeatureSqueezing_ZooAttack':
        # Initialize the feature squeezing defence
        defence = FeatureSqueezing(clip_values=(X_train.min(), X_train.max()), bit_depth=4)

        # Fit the defence with training data
        defence.fit(X_train)

        # Apply the defence on testing data
        x_test_adv = defence(x_test_adv)[0]
        
    if clf_name == 'GaussianAugmentation_ZooAttack':
        # Initialize the Gaussian Augmentation defence
        defence = GaussianAugmentation(sigma=1.0)

        # Apply the Gaussian Augmentation on training data
        X_train_augmented, y_train_augmented = defence(X_train, y_train)

        # Retrain the model on the augmented data
        clf.fit(X_train_augmented, y_train_augmented)
    
    start_time = time.time()
    pred_probs = clf.predict_proba(x_test_adv)
    preds = clf.predict(x_test_adv)
    runtime = time.time() - start_time

    # Evaluate
    auc = roc_auc_score(y_test, pred_probs[:, 1], multi_class='ovr')
    f1 = f1_score(y_test, preds, average='macro')
    logloss = log_loss(y_test, pred_probs)
    accuracy = accuracy_score(y_test, preds)

    return [dataset_name, clf_name, auc, f1, logloss, accuracy, runtime]

# Loop through datasets
all_tasks = []

for dataset_name, dataset in datasets:
    print(dataset_name)
    X, y = dataset.data.fillna(0).values, dataset.target
    try:
        # Perform 5-fold cross-validation
        for clf_name, clf in classifiers.items():
            for i, (train_index, test_index) in enumerate(skf.split(X, y)):
                task = delayed(evaluate_classifier)(dataset_name, dataset, clf_name, clf, train_index, test_index)
                all_tasks.append(task)
    except Exception as e:
        print(f"Error in {clf_name} on {dataset_name}: {e}")

# Execute all tasks in parallel
try:
    results = Parallel(n_jobs=-1)(all_tasks)
except Exception as e:
    print(f"Error in {clf_name} on {dataset_name}: {e}")

# Convert results to DataFrame for easy visualization
results_df_ZooAttack = pd.DataFrame(results, columns=['Dataset', 'Classifier', 'AUC', 'F1', 'LogLoss', 'Accuracy', 'Runtime'])


summary_ZooAttack = results_df_ZooAttack.groupby(['Dataset','Classifier']).agg({
    'AUC': ['mean', 'std'],
    'F1': ['mean', 'std'],
    'LogLoss': ['mean', 'std'],
    'Accuracy': ['mean', 'std'],
    'Runtime': ['mean', 'std']
}).reset_index()

print(summary_ZooAttack)
# Out:
# !ar4.csv
# !bodyfat.csv
# Kaggle_Surgical-deepnet.csv
# MaternalBinary.csv
# OPENML_philippine.csv
# AcousticExtinguisherFire.csv
# acute-inflammation.csv
# acute-nephritis.csv
# AP_Colon_Lung.csv
# backache.csv
# blood.csv
# chess-krvkp.csv
# cloud.csv
# congressional-voting.csv
# credit-approval.csv
# dresses-salesN.csv
# echocardiogram.csv
# haberman-survival.csv
# heart_failure_clinical_records_dataset.csv
# heart-hungarian.csv
# hill-valley.csv
# horse-colic.csv
# ilpd-indian-liver.csv
# no2.csv
# kaggle_REWEMA.csv
# lowbwt.csv
# madelon.csv
# Mesothelioma.csv
# MIMIC2.csv
# molec-biol-promoter.csv
# oil_spill.csv
# oocytes_merluccius_nucleus_4d.csv
# oocytes_trisopterus_nucleus_2f.csv
# ozone.csv
# Parkinson_Multiple_Sound_Recording.csv
# PC1 Software defect prediction.csv
# pd_speech_features.csv
# pima.csv
# Pistachio_28_Features_Dataset.csv
# plasma_retinol.csv
# primary-tumorNumeric.csv
# seismic-bumps.csv
# sleuth_case2002.csv
# spambase.csv
# spect.csv
# spectf.csv
# statlog-australian-credit.csv
# statlog-heart_.csv
# ThoraricSurgery.csv
# triazines.csv
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   0%|          | 0/21 [00:00<?, ?it/s]/home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   0%|          | 0/21 [00:00<?, ?it/s]/home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  19%|█▉        | 4/21 [00:00<00:01, 13.91it/s]/home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  33%|███▎      | 7/21 [00:00<00:01, 11.19it/s]/home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  43%|████▎     | 9/21 [00:00<00:01, 11.24it/s]/home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  57%|█████▋    | 12/21 [00:00<00:00, 15.00it/s]/home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   0%|          | 0/21 [00:00<?, ?it/s]/home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   0%|          | 0/51 [00:00<?, ?it/s]/home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  14%|█▎        | 7/51 [00:00<00:04, 10.83it/s]/home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   0%|          | 0/21 [00:00<?, ?it/s]/home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  45%|████▌     | 10/22 [00:00<00:01, 10.11it/s]/home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   0%|          | 0/51 [00:00<?, ?it/s]/home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   9%|▉         | 2/22 [00:00<00:01, 10.34it/s]/home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   0%|          | 0/22 [00:00<?, ?it/s]/home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   0%|          | 0/51 [00:00<?, ?it/s]/home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  29%|██▊       | 6/21 [00:00<00:01, 10.58it/s]/home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   0%|          | 0/21 [00:00<?, ?it/s]/home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   0%|          | 0/21 [00:00<?, ?it/s]/home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   0%|          | 0/50 [00:00<?, ?it/s]/home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   0%|          | 0/21 [00:00<?, ?it/s]/home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  10%|▉         | 5/51 [00:00<00:04, 10.95it/s]/home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   0%|          | 0/22 [00:00<?, ?it/s]/home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  14%|█▎        | 7/51 [00:00<00:03, 11.02it/s]/home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   0%|          | 0/50 [00:00<?, ?it/s]/home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  95%|█████████▌| 20/21 [00:01<00:00, 11.97it/s]/home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   0%|          | 0/22 [00:00<?, ?it/s]/home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   0%|          | 0/21 [00:00<?, ?it/s]/home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   0%|          | 0/21 [00:00<?, ?it/s]/home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   0%|          | 0/21 [00:00<?, ?it/s]/home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   0%|          | 0/51 [00:00<?, ?it/s]/home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   0%|          | 0/21 [00:00<?, ?it/s]/home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  27%|██▋       | 6/22 [00:00<00:01, 11.17it/s]/home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  14%|█▍        | 3/21 [00:00<00:01, 10.60it/s]/home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   0%|          | 0/50 [00:00<?, ?it/s]/home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  73%|███████▎  | 16/22 [00:01<00:00, 10.59it/s]/home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   6%|▌         | 3/50 [00:00<00:04,  9.93it/s]/home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   0%|          | 0/50 [00:00<?, ?it/s]/home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   0%|          | 0/51 [00:00<?, ?it/s]/home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   0%|          | 0/21 [00:00<?, ?it/s]/home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   0%|          | 0/50 [00:00<?, ?it/s]/home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   0%|          | 0/50 [00:00<?, ?it/s]/home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  14%|█▍        | 3/21 [00:00<00:01,  9.82it/s]/home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   0%|          | 0/21 [00:00<?, ?it/s]/home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   0%|          | 0/50 [00:00<?, ?it/s]/home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   0%|          | 0/51 [00:00<?, ?it/s]/home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   0%|          | 0/51 [00:00<?, ?it/s]/home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   0%|          | 0/50 [00:00<?, ?it/s]/home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   0%|          | 0/22 [00:00<?, ?it/s]/home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   0%|          | 0/50 [00:00<?, ?it/s]/home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  48%|████▊     | 10/21 [00:01<00:01,  7.12it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   6%|▌         | 3/51 [00:00<00:05,  8.64it/s]]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  47%|████▋     | 24/51 [00:02<00:02,  9.58it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  90%|█████████ | 19/21 [00:02<00:00, 10.01it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO: 100%|██████████| 21/21 [00:02<00:00,  8.16it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  57%|█████▋    | 29/51 [00:03<00:02,  9.86it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO: 100%|██████████| 21/21 [00:02<00:00,  7.55it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  52%|█████▏    | 26/50 [00:02<00:02, 10.40it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  50%|█████     | 25/50 [00:02<00:02,  9.71it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  57%|█████▋    | 29/51 [00:03<00:02,  9.95it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  60%|██████    | 30/50 [00:03<00:01, 11.05it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  57%|█████▋    | 29/51 [00:03<00:02,  9.87it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  57%|█████▋    | 29/51 [00:03<00:02,  9.38it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  20%|██        | 10/50 [00:00<00:04,  9.93it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  84%|████████▍ | 42/50 [00:04<00:00, 10.27it/s]/home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  24%|██▎       | 12/51 [00:01<00:04,  9.25it/s]/home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  78%|███████▊  | 40/51 [00:04<00:01,  9.00it/s]/home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  32%|███▏      | 16/50 [00:01<00:03,  9.29it/s]/home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  76%|███████▋  | 39/51 [00:04<00:01,  8.87it/s]/home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  82%|████████▏ | 41/50 [00:04<00:00, 10.07it/s]/home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  33%|███▎      | 17/51 [00:01<00:03,  9.17it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  36%|███▌      | 18/50 [00:01<00:03,  9.24it/s]]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  98%|█████████▊| 49/50 [00:05<00:00,  9.01it/s]]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO: 100%|██████████| 50/50 [00:05<00:00,  9.06it/s]]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  58%|█████▊    | 29/50 [00:03<00:02,  9.68it/s]]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   0%|          | 9/2927 [00:01<05:27,  8.90it/s]]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  76%|███████▌  | 38/50 [00:04<00:01,  8.97it/s]]]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  80%|████████  | 40/50 [00:04<00:01,  8.98it/s]s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  82%|████████▏ | 41/50 [00:04<00:01,  8.97it/s]s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   0%|          | 1/2927 [00:00<05:10,  9.43it/s]]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  96%|█████████▌| 48/50 [00:05<00:00,  9.32it/s]s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   1%|          | 21/2927 [00:02<05:22,  9.00it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   1%|          | 29/2927 [00:03<05:16,  9.15it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  96%|█████████▌| 48/50 [00:05<00:00,  9.23it/s]s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   0%|          | 9/2927 [00:01<05:43,  8.50it/s]]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  98%|█████████▊| 49/50 [00:05<00:00,  9.19it/s]s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   0%|          | 2/2927 [00:00<05:23,  9.04it/s]]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   0%|          | 2/2927 [00:00<05:10,  9.43it/s]]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   1%|          | 15/2927 [00:01<04:49, 10.04it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   0%|          | 3/2927 [00:00<05:30,  8.84it/s]]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   0%|          | 0/2927 [00:00<?, ?it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   1%|▏         | 39/2927 [00:03<04:58,  9.67it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   1%|▏         | 37/2927 [00:03<04:48, 10.03it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   0%|          | 11/2927 [00:01<07:02,  6.90it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   0%|          | 3/2927 [00:00<04:42, 10.35it/s]]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   0%|          | 7/2927 [00:00<05:36,  8.67it/s]]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   1%|          | 34/2927 [00:03<05:30,  8.74it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   1%|          | 28/2927 [00:02<05:00,  9.65it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   0%|          | 6/2927 [00:00<05:24,  8.99it/s]]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   0%|          | 8/2927 [00:00<05:30,  8.83it/s]]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   0%|          | 13/2927 [00:01<05:20,  9.08it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   1%|          | 23/2927 [00:02<05:21,  9.03it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   1%|          | 25/2927 [00:03<05:32,  8.73it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   1%|▏         | 42/2927 [00:04<05:32,  8.67it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   3%|▎         | 82/2927 [00:08<05:18,  8.93it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   2%|▏         | 52/2927 [00:06<05:12,  9.20it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   2%|▏         | 47/2927 [00:05<05:21,  8.96it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   2%|▏         | 45/2927 [00:04<05:24,  8.88it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   2%|▏         | 58/2927 [00:06<05:26,  8.79it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   3%|▎         | 99/2927 [00:10<05:22,  8.77it/s]]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   4%|▍         | 118/2927 [00:12<05:19,  8.78it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  19%|█▉        | 39/203 [00:04<00:18,  8.96it/s]]]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   3%|▎         | 95/2927 [00:10<05:19,  8.88it/s]]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   3%|▎         | 96/2927 [00:10<05:19,  8.86it/s]]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   4%|▍         | 111/2927 [00:12<05:17,  8.88it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   3%|▎         | 98/2927 [00:10<05:16,  8.93it/s]]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   8%|▊         | 225/2927 [00:25<05:00,  9.00it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   9%|▉         | 278/2927 [00:31<04:58,  8.86it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   7%|▋         | 203/2927 [00:28<07:17,  6.23it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   6%|▌         | 170/2927 [00:26<07:21,  6.24it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  10%|▉         | 292/2927 [00:32<04:50,  9.06it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   9%|▉         | 273/2927 [00:30<04:48,  9.19it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  79%|███████▉  | 161/203 [00:18<00:04,  8.97it/s]]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   9%|▉         | 277/2927 [00:31<04:54,  8.99it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  10%|█         | 300/2927 [00:33<04:56,  8.87it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   9%|▉         | 259/2927 [00:30<05:05,  8.75it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   8%|▊         | 16/203 [00:01<00:20,  8.93it/s]s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  21%|██        | 43/203 [00:04<00:17,  8.92it/s]s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  61%|██████    | 123/203 [00:13<00:08,  9.52it/s]]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  33%|███▎      | 68/203 [00:07<00:15,  8.73it/s]s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  15%|█▌        | 450/2927 [00:50<04:36,  8.96it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  12%|█▏        | 346/2927 [00:49<05:13,  8.24it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  16%|█▋        | 477/2927 [00:53<04:17,  9.50it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   6%|▋         | 13/203 [00:01<00:21,  8.74it/s]s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  16%|█▋        | 481/2927 [00:53<04:16,  9.52it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  16%|█▌        | 465/2927 [00:52<04:39,  8.82it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  17%|█▋        | 486/2927 [00:54<04:55,  8.26it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  16%|█▌        | 470/2927 [01:08<04:39,  8.80it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  82%|████████▏ | 166/203 [00:19<00:04,  8.39it/s]]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  23%|██▎       | 659/2927 [01:12<03:56,  9.58it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  22%|██▏       | 640/2927 [01:12<04:20,  8.77it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  23%|██▎       | 668/2927 [01:15<04:22,  8.60it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  24%|██▍       | 707/2927 [01:18<03:17, 11.22it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  29%|██▊       | 841/2927 [01:34<03:56,  8.81it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  29%|██▉       | 858/2927 [01:36<03:52,  8.89it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  30%|██▉       | 865/2927 [01:37<03:51,  8.90it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  44%|████▍     | 1296/2927 [02:25<03:03,  8.87it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  44%|████▎     | 1279/2927 [02:29<03:01,  9.08it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  46%|████▌     | 1347/2927 [02:31<02:58,  8.87it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ...
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  15%|█▍        | 14/94 [00:01<00:09,  8.43it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  49%|████▉     | 46/94 [00:05<00:05,  8.55it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  93%|█████████▎| 87/94 [00:10<00:00,  8.65it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  21%|██▏       | 20/94 [00:02<00:08,  8.87it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  86%|████████▌ | 81/94 [00:09<00:01,  8.96it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  21%|██▏       | 20/94 [00:02<00:08,  8.89it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  57%|█████▋    | 54/94 [00:06<00:04,  8.78it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  80%|███████▉  | 75/94 [00:08<00:02,  6.95it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  57%|█████▋    | 54/94 [00:06<00:05,  8.00it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  64%|██████▍   | 60/94 [00:07<00:04,  8.33it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  77%|███████▋  | 72/94 [00:08<00:02,  8.15it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  83%|████████▎ | 78/94 [00:09<00:02,  7.64it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  24%|██▍       | 9/37 [00:01<00:03,  8.71it/s]]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO: 100%|██████████| 94/94 [00:11<00:00,  8.00it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  24%|██▎       | 9/38 [00:01<00:03,  8.95it/s]]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  84%|████████▍ | 31/37 [00:03<00:00,  8.74it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  54%|█████▍    | 20/37 [00:02<00:01,  8.76it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  65%|██████▍   | 24/37 [00:02<00:01,  8.73it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  34%|███▍      | 13/38 [00:01<00:02,  8.76it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  24%|██▍       | 9/37 [00:00<00:03,  9.07it/s]]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   5%|▌         | 2/37 [00:00<00:03,  8.78it/s]]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  57%|█████▋    | 21/37 [00:02<00:01,  9.08it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  46%|████▌     | 17/37 [00:02<00:02,  8.39it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO: 100%|██████████| 37/37 [00:04<00:00,  8.82it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  89%|████████▉ | 34/38 [00:03<00:00,  8.77it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:   8%|▊         | 3/37 [00:00<00:04,  8.48it/s]]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  51%|█████▏    | 19/37 [00:02<00:02,  8.86it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  46%|████▌     | 17/37 [00:01<00:02,  8.77it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  54%|█████▍    | 20/37 [00:02<00:01,  9.13it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  84%|████████▍ | 32/38 [00:06<00:01,  4.21it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  54%|█████▍    | 20/37 [00:02<00:01,  8.88it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  73%|███████▎  | 27/37 [00:03<00:01,  9.00it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  49%|████▊     | 18/37 [00:02<00:02,  8.63it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  13%|█▎        | 5/38 [00:00<00:03,  8.93it/s]]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  16%|█▌        | 6/38 [00:00<00:03,  8.91it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  51%|█████▏    | 19/37 [00:02<00:01,  9.20it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  24%|██▍       | 9/37 [00:01<00:03,  8.90it/s]]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  30%|██▉       | 11/37 [00:01<00:02,  9.10it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  49%|████▊     | 18/37 [00:01<00:02,  9.05it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  59%|█████▉    | 22/37 [00:02<00:01,  9.08it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  43%|████▎     | 16/37 [00:01<00:02,  8.87it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO:  38%|███▊      | 14/37 [00:01<00:02,  8.98it/s]
# /home/seffi/.conda/envs/WBTTA/lib/python3.8/site-packages/sklearn/utils/deprecation.py:103: FutureWarning: Attribute `n_features_` was deprecated in version 1.0 and will be removed in 1.2. Use `n_features_in_` instead.
#   warnings.warn(msg, category=FutureWarning)
# ZOO: 100%|██████████| 37/37 [00:04<00:00,  8.26it/s]
#            Dataset                                        Classifier  \
#
# 0         !ar4.csv                        FeatureSqueezing_ZooAttack
# 1         !ar4.csv   MonteCarloRandomForest_Agreement_Prob_ZooAttack
# 2         !ar4.csv  MonteCarloRandomForest_Confidence_Prob_ZooAttack
# 3         !ar4.csv       MonteCarloRandomForest_Depth_Prob_ZooAttack
# 4         !ar4.csv    MonteCarloRandomForest_Distance_Prob_ZooAttack
# ..             ...                                               ...
# 345  triazines.csv  MonteCarloRandomForest_Confidence_Prob_ZooAttack
# 346  triazines.csv       MonteCarloRandomForest_Depth_Prob_ZooAttack
# 347  triazines.csv    MonteCarloRandomForest_Distance_Prob_ZooAttack
# 348  triazines.csv         MonteCarloRandomForest_Fix_Prob_ZooAttack
# 349  triazines.csv                            RandomForest_ZooAttack
#
#           AUC                  F1             LogLoss            Accuracy  \
#          mean       std      mean       std      mean       std      mean
# 0    0.590686  0.067145  0.448421  0.001441  3.437548  2.791089  0.812987
# 1    0.829739  0.123686  0.724949  0.075304  1.578587  2.086582  0.868831
# 2    0.861765  0.078451  0.695854  0.062722  0.541986  0.084410  0.859740
# 3    0.847712  0.128718  0.724949  0.075304  0.440810  0.062425  0.868831
# 4    0.860948  0.124607  0.695854  0.062722  0.472627  0.079946  0.859740
# ..        ...       ...       ...       ...       ...       ...       ...
# 345  0.686791  0.092971  0.645745  0.089121  0.670293  0.036765  0.655761
# 346  0.728019  0.094581  0.672283  0.056049  0.674041  0.006861  0.688193
# 347  0.799042  0.069255  0.744066  0.070905  0.610591  0.080447  0.757468
# 348  0.713766  0.111733  0.641161  0.070257  0.653232  0.016127  0.655334
# 349  0.617370  0.110131  0.473382  0.109559  1.723273  0.404532  0.505548
#
#                  Runtime
#           std       mean       std
# 0    0.004742   0.003274  0.000534
# 1    0.040598   5.374105  0.906562
# 2    0.033859  13.161130  2.067501
# 3    0.040598   1.210171  0.196778
# 4    0.033859  11.126527  1.544636
# ..        ...        ...       ...
# 345  0.091038  38.032155  4.673151
# 346  0.058946   3.534823  0.134690
# 347  0.064902  30.404632  2.277328
# 348  0.081804   3.310965  0.133056
# 349  0.100888   0.003792  0.000089
#
# [350 rows x 12 columns]

# %%
summary_wo.append(summary_ZooAttack).sort_values(by='Dataset').to_csv('50ds_rf_summaryV5.csv',index=False)

# %%
summary_wo.sort_values(by='Dataset').to_csv('50ds_wo_rf_summaryV5.csv',index=False)

# %%
summary_ZooAttack.sort_values(by='Dataset').to_csv('50ds_zoo_rf_summaryV5.csv',index=False)
